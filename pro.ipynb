# %%
from dotenv import load_dotenv
from langchain_community.utilities import GoogleSerperAPIWrapper

load_dotenv()
# Out:
# True

# %%
search = GoogleSerperAPIWrapper()

search.run("india's national fruit?")
# Out:
# 'The mango is the national fruit of India, Pakistan, and the Philippines.It is the national tree of Bangladesh. In India, the ... Scientifically termed Mangifera indica, mango represents our country\'s agrarian legacy – as it\'s indigenous to the Indian subcontinent. The Mango (Known as "Aam" in Hindi), scientific name - Mangifera indica, is the national fruit of India. The fruit Mango is one of the most widely cultivated ... Mango is India\'s national fruit. Indians have traditionally regarded ripe meaty mangoes as the King of all fruits, and they are undoubtedly delicious. The mango fruit was brought to Portugal and Britain by traders and colonizers. In South Asia, mangoes are so valued that they are considered the ... National Fruit of India - Mango - Designated as the King of all fruits by Indians since long, ripe fleshy mangoes are certainly very tasty. The raw ones can be ... Mango is the National fruit of India and it is one of the most favourite fruits , so enjoy your summer 
# ...
